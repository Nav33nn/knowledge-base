# %%
import pandas as pd
ad = pd.read_csv('advertising.csv')
ad.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
ad = (ad - ad.mean())/ad.std()
ad.head()
# Out:
#          TV     Radio  Newspaper     Sales
# 0  0.967425  0.979066   1.774493  1.548168
# 1 -1.194379  1.080097   0.667903 -0.694304
# 2 -1.512360  1.524637   1.779084 -0.905135
# 3  0.051919  1.214806   1.283185  0.858177
# 4  0.393196 -0.839507   1.278593 -0.215143

# %%
# Putting feature variable to X
X = ad[['TV','Radio','Newspaper']]
# Putting response variable to y
y = ad['Sales']

# %%
X['intercept'] = 1
X = X.reindex_axis(['intercept','TV','Radio','Newspaper'], axis=1)

# %%
X.head()
# Out:
#    intercept        TV     Radio  Newspaper
# 0          1  0.967425  0.979066   1.774493
# 1          1 -1.194379  1.080097   0.667903
# 2          1 -1.512360  1.524637   1.779084
# 3          1  0.051919  1.214806   1.283185
# 4          1  0.393196 -0.839507   1.278593

# %%
import numpy as np
X = np.array(X)
y = np.array(y)

# %%
# Theta needed to be changed with the number of response varaible used.
theta = np.matrix(np.array([0,0,0,0])) 
alpha = 0.01
iterations = 1000

# %%
import numpy as np

def compute_cost(X, y, theta):
    return np.sum(np.square(np.matmul(X, theta) - y)) / (2 * len(y))

# %%
def gradient_descent_multi(X, y, theta, alpha, iterations):
    theta = np.zeros(X.shape[1])
    m = len(X)
    gdm_df = pd.DataFrame( columns = ['Bets','cost'])

    for i in range(iterations):
        gradient = (1/m) * np.matmul(X.T, np.matmul(X, theta) - y)
        theta = theta - alpha * gradient
        cost = compute_cost(X, y, theta)
        gdm_df.loc[i] = [theta,cost]

    return gdm_df

# %%
gradient_descent_multi(X, y, theta, alpha, iterations)
# Out:
#                                                   Bets      cost
# 0    [-5.15143483426e-18, 0.00778313302737, 0.00573...  0.487696
# 1    [-1.02140518266e-17, 0.01548441682, 0.01139753...  0.478118
# 2    [-1.53654866608e-17, 0.0231047301663, 0.016993...  0.468760
# 3    [-2.02504679692e-17, 0.0306449421912, 0.022521...  0.459617
# 4    [-2.45137243837e-17, 0.0381059124656, 0.027983...  0.450683
# 5    [-2.88657986403e-17, 0.0454884911142, 0.033378...  0.441955
# 6    [-3.33066907388e-17, 0.0527935189216, 0.038709...  0.433426
# 7    [-3.74811293113e-17, 0.0600218274384, 0.043976...  0.425092
# 8    [-4.19220214098e-17, 0.0671742390844, 0.049180...  0.416949
# 9    [-4.61852778244e-17, 0.0742515672523, 0.054321...  0.408992
# 10   [-5.0359716397e-17, 0.0812546164091, 0.0594009...  0.401217
# 11   [-5.42677014437e-17, 0.0881841821965, 0.064419...  0.393619
# 12   [-5.79980508064e-17, 0.0950410515304, 0.069378...  0.386194
# 13   [-6.15507644852e-17, 0.101826002699, 0.0742778...  0.378938
# 14   [-6.5192296006e-17, 0.108539805461, 0.07911881...  0.371846
# 15   [-6.85673740008e-17, 0.115183221139, 0.0839020...  0.364916
# 16   [-7.18536341537e-17, 0.121757002716, 0.0886282...  0.358143
# 17   [-7.50510764647e-17, 0.128261894931, 0.0932982...  0.351524
# 18   [-7.84261544595e-17, 0.134698634369, 0.0979127...  0.345055
# 19   [-8.12683254026e-17, 0.141067949551, 0.1024723...  0.338731
# 20   [-8.41104963456e-17, 0.14737056103, 0.10697791...  0.332551
# 21   [-8.72191208146e-17, 0.153607181476, 0.1114300...  0.326511
# 22   [-9.01501095996e-17, 0.159778515766, 0.1158294...  0.320606
# 23   [-9.28146448587e-17, 0.165885261071, 0.1201767...  0.314835
# 24   [-9.51239087499e-17, 0.171928106944, 0.1244727...  0.309194
# 25   [-9.71667191152e-17, 0.177907735403, 0.1287180...  0.303679
# 26   [-9.98312543743e-17, 0.183824821017, 0.1329132...  0.298289
# 27   [-1.02051700424e-16, 0.189680030989, 0.1370589...  0.293020
# 28   [-1.04094510789e-16, 0.195474025239, 0.1411559...  0.287868
# 29   [-1.06492592522e-16, 0.201207456484, 0.1452047...  0.282832
# ..                                                 ...       ...
# 970  [2.77533551696e-16, 0.753017049088, 0.53596798...  0.051138
# 971  [2.77666778459e-16, 0.75301751851, 0.535971263...  0.051138
# 972  [2.77466938314e-16, 0.75301798339, 0.535974524...  0.051138
# 973  [2.77644573998e-16, 0.753018443772, 0.53597776...  0.051138
# 974  [2.7726709817e-16, 0.7530188997, 0.53598098242...  0.051138
# 975  [2.77489142775e-16, 0.753019351218, 0.53598418...  0.051138
# 976  [2.77911027524e-16, 0.753019798367, 0.53598735...  0.051138
# 977  [2.77666778459e-16, 0.753020241191, 0.53599051...  0.051138
# 978  [2.77533551696e-16, 0.753020679732, 0.53599365...  0.051138
# 979  [2.7771118738e-16, 0.753021114031, 0.535996771...  0.051138
# 980  [2.77666778459e-16, 0.75302154413, 0.535999868...  0.051138
# 981  [2.77422529393e-16, 0.753021970069, 0.53600294...  0.051138
# 982  [2.77666778459e-16, 0.753022391888, 0.53600600...  0.051138
# 983  [2.77444733854e-16, 0.753022809629, 0.53600904...  0.051138
# 984  [2.77666778459e-16, 0.75302322333, 0.536012063...  0.051138
# 985  [2.77400324933e-16, 0.753023633031, 0.53601506...  0.051138
# 986  [2.77533551696e-16, 0.753024038771, 0.53601804...  0.051138
# 987  [2.77822209682e-16, 0.753024440588, 0.53602100...  0.051138
# 988  [2.77555756156e-16, 0.75302483852, 0.536023949...  0.051138
# 989  [2.77378120472e-16, 0.753025232605, 0.53602687...  0.051138
# 990  [2.77688982919e-16, 0.753025622881, 0.53602977...  0.051138
# 991  [2.77666778459e-16, 0.753026009384, 0.53603266...  0.051138
# 992  [2.77466938314e-16, 0.753026392152, 0.53603553...  0.051138
# 993  [2.77800005222e-16, 0.75302677122, 0.536038386...  0.051138
# 994  [2.77644573998e-16, 0.753027146624, 0.53604121...  0.051138
# 995  [2.77444733854e-16, 0.753027518401, 0.53604403...  0.051138
# 996  [2.77688982919e-16, 0.753027886585, 0.53604682...  0.051138
# 997  [2.77422529393e-16, 0.753028251211, 0.53604960...  0.051138
# 998  [2.77555756156e-16, 0.753028612313, 0.53605236...  0.051138
# 999  [2.77422529393e-16, 0.753028969927, 0.53605511...  0.051138
#
# [1000 rows x 2 columns]

# %%
print(gradient_descent_multi(X, y, theta, alpha, iterations).values[999])
# Out:
# [ array([  2.77422529e-16,   7.53028970e-01,   5.36055111e-01,
#         -3.89429686e-03])
#  0.0511378277805789]

# %%
gradient_descent_multi(X, y, theta, alpha, iterations).reset_index().plot.line(x='index', y=['cost'])
# Out:
# C:\Users\Sumit Shukla\Anaconda3\lib\site-packages\pandas\plotting\_core.py:1716: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   series.name = label

# %%
# import LinearRegression from sklearn
from sklearn.linear_model import LinearRegression

# Representing LinearRegression as lr(Creating LinearRegression Object)
lr = LinearRegression()

#You don't need to specify an object to save the result because 'lr' will take the results of the fitted model.
lr.fit(X, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
print(lr.intercept_)
print(lr.coef_)
# Out:
# 2.6626885691654713e-16
# [ 0.75306591  0.53648155 -0.00433069]
